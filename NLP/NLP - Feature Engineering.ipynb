# %% [markdown]
# ## Feature Engineering
# Creating the new features or transforming your existing features to get the most out of your data
#
# ### 1. Creating the New Features
# 1. Lenght of text
# 2. Percentage of character that are puctuation
# 3. Percentage of character that are capitialized
#
# ### Transformations
# 1. Power transformaions (square, square root, etc)
# 2. Standardizing data
#
# ![image.png](attachment:image.png)
